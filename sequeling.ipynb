# %%
import pandas as pd
import mysql.connector 
from mysql import connector

# %%
dfbus0=pd.read_csv("C:\\Redbus\\df_bus_andhra.csv")
dfbus1=pd.read_csv("C:\\Redbus\\df_bus_assam.csv")
dfbus2=pd.read_csv("C:\\Redbus\\df_bus_bihar.csv")
dfbus3=pd.read_csv("C:\\Redbus\\df_bus_goa.csv")
dfbus4=pd.read_csv("C:\\Redbus\\df_bus_gujurat.csv")
dfbus5=pd.read_csv("C:\\Redbus\\df_bus_himachal.csv")
dfbus6=pd.read_csv("C:\\Redbus\\df_bus_kerala.csv")
dfbus7=pd.read_csv("C:\\Redbus\\df_bus_ksmroadway.csv")
dfbus8=pd.read_csv("C:\\Redbus\\df_bus_meghalaya.csv")
dfbus9=pd.read_csv("C:\\Redbus\\df_bus_psr.csv")
dfbus10=pd.read_csv("C:\\Redbus\\df_bus_rajasthan.csv")
dfbus11=pd.read_csv("C:\\Redbus\\df_bus_royal.csv")
dfbus12=pd.read_csv("C:\\Redbus\\df_bus_telangana.csv")
dfbus13=pd.read_csv("C:\\Redbus\\df_bus_uttar_pradesh.csv")
dfbus14=pd.read_csv("C:\\Redbus\\df_bus_west_bengal.csv")

# %%
dfbus=pd.concat([dfbus0,dfbus1,dfbus2,dfbus3,dfbus4,dfbus5,dfbus6,dfbus7,dfbus8,dfbus9,dfbus10,dfbus11,dfbus12,dfbus13,dfbus14])
# Out:
# C:\Users\Harsha\AppData\Local\Temp\ipykernel_16232\227964875.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dfbus=pd.concat([dfbus0,dfbus1,dfbus2,dfbus3,dfbus4,dfbus5,dfbus6,dfbus7,dfbus8,dfbus9,dfbus10,dfbus11,dfbus12,dfbus13,dfbus14])

# %%
dfbus
# Out:
#                           Bus_name  \
# 0                    APSRTC - 9316
# 1                   APSRTC - 35189
# 2                    APSRTC - 4046
# 3                    APSRTC - 9651
# 4                    APSRTC - 9654
# ..                             ...
# 36                    KVS Holidays
# 37  Shree Krishna Shtabadi Travels
# 38         Abhay Travels (I.R.T.C)
# 39               Shivendra Travels
# 40  Shree Krishna Shtabadi Travels
#
#                                           Bus_type Start_time End_time  \
# 0           SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)      20:20    04:10
# 1   DOLPHIN CRUISE (VOLVO / SCANIA A.C Multi Axle)      20:30    01:20
# 2           SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)      21:00    03:40
# 3           SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)      21:00    04:41
# 4           SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)      21:40    05:20
# ..                                             ...        ...      ...
# ...

# %%
dfbus.isna().sum()
# Out:
# Bus_name           333
# Bus_type           342
# Start_time         333
# End_time           333
# Total_duration     333
# Price              334
# Seats_Available    340
# Ratings            334
# Route_name           0
# Route_link           0
# dtype: int64

# %%
dfbus.shape
# Out:
# (1242, 10)

# %%
dfbus['Route_link'].unique
# Out:
# <bound method Series.unique of 0     https://www.redbus.in/bus-tickets/vijayawada-t...
# 1     https://www.redbus.in/bus-tickets/vijayawada-t...
# 2     https://www.redbus.in/bus-tickets/vijayawada-t...
# 3     https://www.redbus.in/bus-tickets/vijayawada-t...
# 4     https://www.redbus.in/bus-tickets/vijayawada-t...
#                             ...
# 36    https://www.redbus.in/bus-tickets/delhi-to-far...
# 37    https://www.redbus.in/bus-tickets/delhi-to-far...
# 38    https://www.redbus.in/bus-tickets/delhi-to-far...
# 39    https://www.redbus.in/bus-tickets/delhi-to-far...
# 40    https://www.redbus.in/bus-tickets/delhi-to-far...
# Name: Route_link, Length: 1242, dtype: object>

# %%
dfbus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1242 entries, 0 to 40
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         909 non-null    object
#  1   Bus_type         900 non-null    object
#  2   Start_time       909 non-null    object
#  3   End_time         909 non-null    object
#  4   Total_duration   909 non-null    object
#  5   Price            908 non-null    float64
#  6   Seats_Available  902 non-null    object
#  7   Ratings          908 non-null    object
#  8   Route_name       1242 non-null   object
#  9   Route_link       1242 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 106.7+ KB

# %%
dfbus['Start_time']=pd.to_datetime(dfbus['Start_time'],format="%H:%M").dt.strftime("%H:%M")
dfbus['End_time']=pd.to_datetime(dfbus['End_time'],format="%H:%M").dt.strftime('%H:%M')

# %%
print(type(dfbus['End_time'][0]))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(type(dfbus['Start_time'][0]))
# Out:
# <class 'pandas.core.series.Series'>

# %%
dfbus['Start_time']
# Out:
# 0     20:20
# 1     20:30
# 2     21:00
# 3     21:00
# 4     21:40
#       ...
# 36    21:30
# 37    21:00
# 38    20:30
# 39    21:00
# 40    21:00
# Name: Start_time, Length: 1242, dtype: object

# %%
dfbus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1242 entries, 0 to 40
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         909 non-null    object
#  1   Bus_type         900 non-null    object
#  2   Start_time       909 non-null    object
#  3   End_time         909 non-null    object
#  4   Total_duration   909 non-null    object
#  5   Price            908 non-null    float64
#  6   Seats_Available  902 non-null    object
#  7   Ratings          908 non-null    object
#  8   Route_name       1242 non-null   object
#  9   Route_link       1242 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 139.0+ KB

# %%
dfbus['Ratings']
# Out:
# 0     4.4\n67
# 1     4.0\n43
# 2     4.5\n38
# 3     4.4\n30
# 4     3.8\n35
#        ...
# 36    2.2\n18
# 37    2.4\n23
# 38     1.0\n2
# 39
# 40        2.4
# Name: Ratings, Length: 1242, dtype: object

# %%
dfbus['Ratings'] = dfbus['Ratings'].str.split('\n').str[0]
dfbus['Ratings'] = pd.to_numeric(dfbus['Ratings'], errors='coerce')

# %%
dfbus['Ratings']
# Out:
# 0     4.4
# 1     4.0
# 2     4.5
# 3     4.4
# 4     3.8
#      ...
# 36    2.2
# 37    2.4
# 38    1.0
# 39    NaN
# 40    2.4
# Name: Ratings, Length: 1242, dtype: float64

# %%
dfbus.shape
# Out:
# (1242, 10)

# %%
dfbus['Ratings'].dtype
# Out:
# dtype('float64')

# %%
dfbus['Seats_Available'].dtype
# Out:
# dtype('O')

# %%
dfbus['Seats_Available']
# Out:
# 0       1 Seat available
# 1     24 Seats available
# 2      3 Seats available
# 3       1 Seat available
# 4       1 Seat available
#              ...
# 36    31 Seats available
# 37    44 Seats available
# 38    30 Seats available
# 39      1 Seat available
# 40    32 Seats available
# Name: Seats_Available, Length: 1242, dtype: object

# %%
dfbus['Seats_Available']=dfbus['Seats_Available'].str.replace("Seats available","").str[0]
dfbus[dfbus['Seats_Available']==" "]
len(dfbus[dfbus['Seats_Available']==0])
# Out:
# 0

# %%
dfbus['Seats_Available']
# Out:
# 0     1
# 1     2
# 2     3
# 3     1
# 4     1
#      ..
# 36    3
# 37    4
# 38    3
# 39    1
# 40    3
# Name: Seats_Available, Length: 1242, dtype: object

# %%
dfbus['Seats_Available'] = dfbus['Seats_Available'].fillna(0).astype(int)

# %%
dfbus['Seats_Available']=dfbus['Seats_Available'].astype(int)

dfbus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1242 entries, 0 to 40
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         909 non-null    object
#  1   Bus_type         900 non-null    object
#  2   Start_time       909 non-null    object
#  3   End_time         909 non-null    object
#  4   Total_duration   909 non-null    object
#  5   Price            908 non-null    float64
#  6   Seats_Available  1242 non-null   int64
#  7   Ratings          903 non-null    float64
#  8   Route_name       1242 non-null   object
#  9   Route_link       1242 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 139.0+ KB

# %%
dfbus['Price'].dtype
# Out:
# dtype('float64')

# %%
dfbus[dfbus['Price']==" "]
dfbus['Price'].unique()
# Out:
# array([ 436.  ,  603.  ,  469.  ,  567.  ,  781.  ,  480.  ,  730.  ,
#         630.  , 1079.  ,  679.  ,  690.  ,  383.  ,  239.  ,  281.  ,
#         269.  , 5000.  ,  280.  ,  398.  ,  399.  ,  314.  ,  599.  ,
#         700.  ,  729.  ,  539.  ,  549.  ,  284.  ,  425.  ,  506.  ,
#         362.  ,  799.  ,  670.  ,  699.  ,  719.  ,  439.  ,  526.  ,
#         467.  ,  656.  ,  459.  ,  550.  ,  500.  ,  605.  ,  671.  ,
#         555.  ,  805.  ,  624.  ,  590.  ,  900.  ,  499.  ,  415.  ,
#         412.  ,  655.  ,  556.  ,  852.  ,  855.  , 1000.  ,  684.  ,
#         890.  ,  638.  ,  800.  ,  220.  ,  186.  ,  217.  ,  277.  ,
#         304.  ,  229.  ,  200.  ,  215.  ,  359.  ,  716.96,  559.  ,
#         850.  ,  999.  ,  919.  , 1039.  , 1327.  ,  828.  ,  509.  ,
#         306.  ,  266.  ,  302.  ,  340.  ,  205.  ,  225.  ,  301.  ,
#        3999.  ,  749.  , 3500.  ,  565.  ,  450.  ,  600.  ,  620.  ,
# ...

# %%
dfbus['Price']=dfbus['Price'].astype(float).round(2)
dfbus['Price']
# Out:
# 0      436.0
# 1      603.0
# 2      469.0
# 3      469.0
# 4      469.0
#        ...
# 36     719.0
# 37     600.0
# 38    1300.0
# 39    3500.0
# 40    1200.0
# Name: Price, Length: 1242, dtype: float64

# %%
dfbus['Price'] = dfbus['Price'].fillna(0.0).astype(float).round(2)
dfbus['Price']
# Out:
# 0      436.0
# 1      603.0
# 2      469.0
# 3      469.0
# 4      469.0
#        ...
# 36     719.0
# 37     600.0
# 38    1300.0
# 39    3500.0
# 40    1200.0
# Name: Price, Length: 1242, dtype: float64

# %%
dfbus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1242 entries, 0 to 40
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         909 non-null    object
#  1   Bus_type         900 non-null    object
#  2   Start_time       909 non-null    object
#  3   End_time         909 non-null    object
#  4   Total_duration   909 non-null    object
#  5   Price            1242 non-null   float64
#  6   Seats_Available  1242 non-null   int64
#  7   Ratings          903 non-null    float64
#  8   Route_name       1242 non-null   object
#  9   Route_link       1242 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 139.0+ KB

# %%
dfbus[dfbus['Total_duration']==" "]
dfbus['Total_duration'].unique()
# Out:
# array(['07h 50m', '04h 50m', '06h 40m', '07h 41m', '07h 40m', '06h 14m',
#        '05h 05m', '08h 07m', '06h 25m', '07h 00m', '06h 05m', '05h 57m',
#        '07h 30m', '06h 10m', '03h 50m', '03h 55m', '04h 15m', '04h 10m',
#        '03h 10m', '04h 00m', '04h 25m', '03h 40m', '06h 00m', '05h 40m',
#        '05h 55m', '05h 45m', '05h 35m', '05h 50m', '04h 30m', '06h 35m',
#        '04h 45m', '06h 45m', '05h 15m', '03h 45m', '05h 58m', '07h 25m',
#        '08h 00m', '05h 00m', '05h 56m', '07h 16m', '06h 15m', '07h 45m',
#        '04h 35m', '07h 10m', '06h 30m', '06h 20m', '09h 00m', '09h 20m',
#        '09h 30m', '08h 55m', '10h 25m', '08h 15m', '08h 45m', '09h 21m',
#        '08h 40m', '08h 30m', '08h 05m', '07h 51m', '08h 36m', '09h 06m',
#        '06h 34m', '07h 27m', '06h 28m', '07h 20m', '06h 33m', '05h 30m',
#        '06h 42m', '06h 55m', '07h 17m', '07h 03m', '08h 10m', '05h 25m',
#        '04h 40m', '03h 15m', '03h 30m', '02h 15m', '03h 01m', '04h 05m',
# ...

# %%
dfbus['Bus_type'].unique()
# Out:
# array(['SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)',
#        'DOLPHIN CRUISE (VOLVO / SCANIA A.C Multi Axle)',
#        'INDRA(A.C. Seater)', 'VENNELA (A.C. SLEEPER)',
#        'Electric A/C Seater (2+2)', 'A/C Sleeper (2+1)',
#        'Non A/C Seater / Sleeper (2+1)', 'A/C Seater / Sleeper (2+1)',
#        'METRO LUXURY A/C', 'ULTRA DELUXE (NON-AC, 2+2 PUSH BACK)',
#        'SAPTAGIRI EXPRESS', 'Express(Non AC Seater)',
#        'Volvo 9600 Multi-Axle A/C Sleeper (2+1)',
#        'Scania AC Multi Axle Sleeper (2+1)',
#        'Bharat Benz A/C Sleeper (2+1)',
#        'Bharat Benz A/C Seater /Sleeper (2+1)',
#        'AMARAVATHI (VOLVO / SCANIA A.C Multi Axle)',
#        'NON A/C Sleeper (2+1)', 'STAR LINER(NON-AC SLEEPER 2+1)',
#        'A/C Seater/Sleeper (2+1)', 'Volvo Multi-Axle A/C Sleeper (2+1)',
#        'AC Sleeper (2+1)',
#        'Volvo Multi-Axle I-Shift A/C Semi Sleeper (2+2)',
#        'NON A/C Seater/ Sleeper (2+1)',
#        'NON A/C Semi Sleeper / Sleeper (2+1)',
# ...

# %%
dfbus[dfbus['Route_name']==" "]
dfbus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1242 entries, 0 to 40
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         909 non-null    object
#  1   Bus_type         900 non-null    object
#  2   Start_time       909 non-null    object
#  3   End_time         909 non-null    object
#  4   Total_duration   909 non-null    object
#  5   Price            1242 non-null   float64
#  6   Seats_Available  1242 non-null   int64
#  7   Ratings          903 non-null    float64
#  8   Route_name       1242 non-null   object
#  9   Route_link       1242 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 139.0+ KB

# %%
dfbus.to_csv("C:/Redbus/dfbus.csv",index=False)

# %%
dfbus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1242 entries, 0 to 40
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         909 non-null    object
#  1   Bus_type         900 non-null    object
#  2   Start_time       909 non-null    object
#  3   End_time         909 non-null    object
#  4   Total_duration   909 non-null    object
#  5   Price            1242 non-null   float64
#  6   Seats_Available  1242 non-null   int64
#  7   Ratings          903 non-null    float64
#  8   Route_name       1242 non-null   object
#  9   Route_link       1242 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 139.0+ KB

# %%
mydb= connector.connect(
            host="localhost",
            port=3306,
            user="root",
            password="123456789",
            
)


cursor = mydb.cursor(buffered=True)

# %%
    cursor.execute("CREATE DATABASE IF NOT EXISTS project")
    print("Database 'project' created or already exists.")
# Out:
# Database 'project' created or already exists.

# %%
query = "use project"
cursor.execute(query)

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS Redbus (
    id INT AUTO_INCREMENT PRIMARY KEY,
    busname VARCHAR(255),
    route_name VARCHAR(255),
    bustype VARCHAR(255),
    departing_time VARCHAR(255),
    duration VARCHAR(255),
    reaching_time VARCHAR(255),
    star_rating FLOAT,
    price DECIMAL(10, 2),
    seats_available INT,
    route_link VARCHAR(255)
);
""")

# %%
dfbus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1242 entries, 0 to 40
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         909 non-null    object
#  1   Bus_type         900 non-null    object
#  2   Start_time       909 non-null    object
#  3   End_time         909 non-null    object
#  4   Total_duration   909 non-null    object
#  5   Price            1242 non-null   float64
#  6   Seats_Available  1242 non-null   int64
#  7   Ratings          903 non-null    float64
#  8   Route_name       1242 non-null   object
#  9   Route_link       1242 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 139.0+ KB

# %%
dfbus.fillna({
    'Bus_name': 'Unknown',
    'Route_name': 'Unknown',
    'Bus_type': 'Unknown',
    'Start_time': '00:00',
    'Total_duration': '00:00',
    'End_time': '00:00',
    'Ratings': 0.0,
    'Price': 0.0,
    'Seats_Available': 0,
    'Route_link': ''
}, inplace=True)

# %%
dfbus['Seats_Available'] = dfbus['Seats_Available'].astype(int)
dfbus['Price'] = dfbus['Price'].astype(float).round(2)
dfbus['Ratings'] = dfbus['Ratings'].astype(float).round(1)

# %%
sql_query = """
        INSERT INTO Redbus (
            busname, route_name, bustype, departing_time, duration, reaching_time,
            star_rating, price, seats_available,route_link
        ) VALUES (
            # %s, %s, %s, %s, %s, %s, %s, %s, %s, %s
        );
        """
        
        # Iterate over DataFrame rows
for index, row in dfbus.iterrows():
            
            # Execute the query with parameters
            cursor.execute(sql_query, (
                row['Bus_name'],
                row['Route_name'],
                row['Bus_type'],
                row['Start_time'],
                row['Total_duration'],
                row['End_time'],
                row['Ratings'],
                row['Price'],
                row['Seats_Available'],
                row['Route_link'],
))
mydb.commit()

# %%
cursor.execute("SELECT * FROM Redbus")

out = cursor.fetchall()

# !pip install tabulate
from tabulate import tabulate

print(tabulate(out,headers=[i[0] for i in cursor.description]))
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   id  busname                                                 route_name                                     bustype                                          departing_time    duration    reaching_time      star_rating    price    seats_available  route_link
# ----  ------------------------------------------------------  ---------------------------------------------  -----------------------------------------------  ----------------  ----------  ---------------  -------------  -------  -----------------  ----------------------------------------------------------------------------
# ...

# %%
dfbus['Price'].mean()
# Out:
# np.float64(410.24026570048306)

# %%
min(dfbus['Price'])
# Out:
# 0.0

# %%
min(dfbus['Ratings'])
# Out:
# 0.0

# %%
# Minimum price excluding 0
min_price = dfbus[dfbus['Price'] > 0]['Price'].min()

# Minimum rating excluding 0
min_rating = dfbus[dfbus['Ratings'] > 0]['Ratings'].min()

# Maximum rating excluding 0
max_rating = dfbus[dfbus['Ratings'] > 0]['Ratings'].max()

print(f"Minimum Price (excluding 0): {min_price}")
print(f"Minimum Rating (excluding 0): {min_rating}")
print(f"Maximum Rating (excluding 0): {max_rating}")
# Out:
# Minimum Price (excluding 0): 120.0
# Minimum Rating (excluding 0): 1.0
# Maximum Rating (excluding 0): 5.0
